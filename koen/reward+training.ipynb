# %%
import torch
print(torch.cuda.is_available())  # Should be True now
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 4070 Laptop GPU

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from sim_class import Simulation

class OT2Env(gym.Env):
    def __init__(self, render=False, max_steps=1000):
        super(OT2Env, self).__init__()
        self.render = render
        self.max_steps = max_steps

        # Create the simulation environment
        self.sim = Simulation(num_agents=1)

        # Define action and observation space
        # Action space: x, y, z velocities (each between -1 and 1)
        self.action_space = spaces.Box(
            low=-1, 
            high=1, 
            shape=(3,), 
            dtype=np.float32
        )
        
        # Observation space: [pipette_x, pipette_y, pipette_z, goal_x, goal_y, goal_z]
        self.observation_space = spaces.Box(
            low=-np.inf, 
            high=np.inf, 
            shape=(6,), 
            dtype=np.float32
        )

        # Define working area bounds (adjust these based on your OT-2 specs)
        self.x_bounds = (-0.187, 0.253)
        self.y_bounds = (-0.171, 0.220)
        self.z_bounds = (0.168, 0.290)

        # keep track of the number of steps
        self.steps = 0
        
        # Initialize goal position
        self.goal_position = None

    def _get_pipette_position(self, state):
        """Helper function to extract pipette position from state"""
        robot_key = [k for k in state.keys() if "robotId" in k][0]
        return np.array(state[robot_key]["pipette_position"], dtype=np.float32)

    def reset(self, seed=None, options=None):
        # being able to set a seed is required for reproducibility
        if seed is not None:
            np.random.seed(seed)
            # Also set the action space seed
            self.action_space.seed(seed)
            self.observation_space.seed(seed)

        # Reset the state of the environment to an initial state
        # set a random goal position for the agent
        self.goal_position = np.array([
            np.random.uniform(self.x_bounds[0], self.x_bounds[1]),
            np.random.uniform(self.y_bounds[0], self.y_bounds[1]),
            np.random.uniform(self.z_bounds[0], self.z_bounds[1])
        ], dtype=np.float32)
        
        # Call the environment reset function
        observation = self.sim.reset(num_agents=1)
        
        # Extract pipette position from observation using dynamic robot_id
        pipette_pos = self._get_pipette_position(observation)
        
        # Combine pipette position and goal position
        observation = np.concatenate([pipette_pos, self.goal_position])

        # Reset the number of steps
        self.steps = 0

        return observation, {}

    def step(self, action):
    # Execute one time step
        action_input = np.append(action, 0)
        observation = self.sim.run([action_input])
        pipette_pos = self._get_pipette_position(observation)
        observation = np.concatenate([pipette_pos, self.goal_position])

        if not hasattr(self, 'prev_distance'):
            self.prev_distance = np.linalg.norm(pipette_pos - self.goal_position)
        
        distance = np.linalg.norm(pipette_pos - self.goal_position)
        
        # Component 1: Progress reward more reward if you are closer to goal
        progress = (self.prev_distance - distance) * 10.0
        
        # Component 2: Distance-based reward the bigger the distance it gives less reward
        distance_reward = np.exp(-distance * 3.0)
        
        # Component 3: Action smoothness penalty (discourage jerky movements)
        action_penalty = -0.01 * np.linalg.norm(action)
        
        # Component 4: Time penalty the longer the model takes the more penalty
        time_penalty = -0.1
        
        # Combine all components
        reward = progress + distance_reward + action_penalty + time_penalty
        
        # Check completion
        # dont set trashhold to 0.0001 its not reachable
        threshold = 0.005
        if distance < threshold:
            terminated = True
            reward += 100.0
        else:
            terminated = False
        
        self.prev_distance = distance
        truncated = self.steps >= self.max_steps
        info = {'distance': float(distance), 'progress': float(progress)}
        self.steps += 1
        
        return observation, float(reward), terminated, truncated, info

    def render(self, mode='human'):
        pass
    
    def close(self):
        self.sim.close()

# %%
from stable_baselines3.common.env_checker import check_env
#from ot2_env_wrapper import OT2Env
import numpy as np

# First, check if the environment is valid
print("Checking environment...")
env = OT2Env()
check_env(env)
print("Environment check passed!")

# Now run some test episodes
print("\nRunning test episodes...")
num_episodes = 5

for episode in range(num_episodes):
    obs, info = env.reset()
    done = False
    step = 0
    total_reward = 0

    print(f"\n--- Episode {episode + 1} ---")
    print(f"Starting position: {obs[:3]}")
    print(f"Goal position: {obs[3:]}")

    while not done:
        # Take a random action from the environment's action space
        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)
        
        total_reward += reward
        done = terminated or truncated

        step += 1
        
        if done:
            print(f"\nEpisode finished after {step} steps")
            print(f"Total reward: {total_reward:.2f}")
            print(f"Terminated: {terminated}, Truncated: {truncated}")
            break

env.close()
print("\nTesting complete!")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Checking environment...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 # First, check if the environment is valid
#       6 print("Checking environment...")
# ----> 7 env = OT2Env()
#       8 check_env(env)
#       9 print("Environment check passed!")
#
# NameError: name 'OT2Env' is not defined

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import CheckpointCallback
#from ot2_env_wrapper import OT2Env
import os
import time
from datetime import datetime, timedelta

# Create directories
os.makedirs("models", exist_ok=True)
os.makedirs("logs", exist_ok=True)

# Create only ONE environment
env = OT2Env(render=False, max_steps=1000)

# Checkpoint callback only (no eval callback)
checkpoint_callback = CheckpointCallback(
    save_freq=10000,
    save_path="./models/",
    name_prefix="ot2_model"
)

# Create the PPO agent
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    tensorboard_log="./logs/tensorboard/",
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    device="cuda"
)

print("=" * 60)
print("Starting training...")
print(f"Total timesteps: 500,000")
print(f"Start time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("=" * 60)

# Start timer
start_time = time.time()

# Train without eval callback
model.learn(
    total_timesteps=500000,
    callback=[checkpoint_callback],
    progress_bar=True
)

# End timer
end_time = time.time()
elapsed_time = end_time - start_time

# Convert to readable format
elapsed_td = timedelta(seconds=int(elapsed_time))
hours, remainder = divmod(int(elapsed_time), 3600)
minutes, seconds = divmod(remainder, 60)

print("=" * 60)
print("Training complete!")
print(f"End time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total training time: {hours}h {minutes}m {seconds}s")
print(f"Time per 1000 timesteps: {(elapsed_time / 500) * 1000:.2f} seconds")
print("=" * 60)

model.save("models/ot2_final_model")
print(f"Model saved to models/ot2_final_model.zip")

env.close()
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ============================================================
# Starting training...
# Total timesteps: 500,000
# Start time: 2025-12-10 11:31:26
# ============================================================
# Logging to ./logs/tensorboard/PPO_7
# c:\Users\koenm\miniconda3\envs\drone_env\lib\site-packages\rich\live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# c:\Users\koenm\miniconda3\envs\drone_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 441      |
# | time/              |          |
# |    fps             | 47       |
# |    iterations      | 1        |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 469         |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 2           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005066338 |
# |    clip_fraction        | 0.0188      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | -0.00991    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00298    |
# |    std                  | 0.999       |
# |    value_loss           | 25.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 443          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 3            |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0064541483 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.559        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 0.987        |
# |    value_loss           | 9.8          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 459          |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 4            |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0048571043 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.825        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00342     |
# |    std                  | 0.988        |
# |    value_loss           | 3.87         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 465         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 5           |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.003909416 |
# |    clip_fraction        | 0.00571     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | -0.247      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.81        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00141    |
# |    std                  | 0.995       |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 479         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 6           |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004208035 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | -0.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.986       |
# |    value_loss           | 5.1         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 470          |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 7            |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0031719126 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | -0.023       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.08         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00145     |
# |    std                  | 0.991        |
# |    value_loss           | 10.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 471          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 8            |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0067374622 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | -0.00115     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 0.998        |
# |    value_loss           | 3.81         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 475         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 9           |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005002351 |
# |    clip_fraction        | 0.0192      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | -0.00373    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 1           |
# |    value_loss           | 4.93        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 472          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 10           |
# |    time_elapsed         | 484          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0059156837 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | -0.00475     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00381     |
# |    std                  | 0.985        |
# |    value_loss           | 3.8          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 479          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 11           |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0034242007 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | -0.00248     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.24         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000578    |
# |    std                  | 0.985        |
# |    value_loss           | 10.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 479         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 12          |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005021482 |
# |    clip_fraction        | 0.0153      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.000113    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.16        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00192    |
# |    std                  | 0.983       |
# |    value_loss           | 5.27        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 483          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 13           |
# |    time_elapsed         | 626          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0062225885 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | -0.00115     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.1          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00298     |
# |    std                  | 0.992        |
# |    value_loss           | 6.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 489         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 14          |
# |    time_elapsed         | 672         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005427707 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.000596    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.692       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00312    |
# |    std                  | 0.987       |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 497         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 15          |
# |    time_elapsed         | 718         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004173086 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.000372    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.535       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00207    |
# |    std                  | 0.981       |
# |    value_loss           | 1.62        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 501          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 16           |
# |    time_elapsed         | 764          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0053154863 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 0.0008       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.52         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00283     |
# |    std                  | 0.984        |
# |    value_loss           | 3.16         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 502          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 17           |
# |    time_elapsed         | 812          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0041031297 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0.000441     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.12         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00326     |
# |    std                  | 0.99         |
# |    value_loss           | 3.07         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 505          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 18           |
# |    time_elapsed         | 862          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0057456857 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.000241     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.07         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0049      |
# |    std                  | 0.99         |
# |    value_loss           | 3.96         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 514         |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 19          |
# |    time_elapsed         | 910         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004404024 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.00146     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00263    |
# |    std                  | 0.991       |
# |    value_loss           | 2.23        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 518          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 20           |
# |    time_elapsed         | 965          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0062195063 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | -0.00311     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00541     |
# |    std                  | 0.996        |
# |    value_loss           | 4.31         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 521          |
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 21           |
# |    time_elapsed         | 1019         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0053020827 |
# |    clip_fraction        | 0.0673       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.000568     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00622     |
# |    std                  | 0.999        |
# |    value_loss           | 2.72         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 530         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 22          |
# |    time_elapsed         | 1076        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010991234 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | -0.0133     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.715       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.994       |
# |    value_loss           | 2.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 536         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 23          |
# |    time_elapsed         | 1132        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006932003 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.0238      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.227       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00928    |
# |    std                  | 0.995       |
# |    value_loss           | 0.858       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 991          |
# |    ep_rew_mean          | 537          |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 24           |
# |    time_elapsed         | 1187         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0047276816 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0.0369       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.434        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00316     |
# |    std                  | 0.984        |
# |    value_loss           | 1.17         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 986         |
# |    ep_rew_mean          | 541         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 25          |
# |    time_elapsed         | 1242        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004818192 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.00592     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.52        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00132    |
# |    std                  | 0.981       |
# |    value_loss           | 9.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | 542         |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 26          |
# |    time_elapsed         | 1298        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007777909 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | -0.16       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.34        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00364    |
# |    std                  | 0.978       |
# |    value_loss           | 7.89        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 965          |
# |    ep_rew_mean          | 547          |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 27           |
# |    time_elapsed         | 1355         |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0047823694 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | 0.00135      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.07         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0032      |
# |    std                  | 0.973        |
# |    value_loss           | 14.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 549          |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 28           |
# |    time_elapsed         | 1409         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0073266034 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0.00768      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.642        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0043      |
# |    std                  | 0.971        |
# |    value_loss           | 7.02         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 950         |
# |    ep_rew_mean          | 548         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 29          |
# |    time_elapsed         | 1464        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005139434 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.07        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.822       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00325    |
# |    std                  | 0.962       |
# |    value_loss           | 7           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 932          |
# |    ep_rew_mean          | 545          |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 30           |
# |    time_elapsed         | 1520         |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0062119984 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | -0.0387      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00416     |
# |    std                  | 0.963        |
# |    value_loss           | 7.91         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | 547         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 31          |
# |    time_elapsed         | 1578        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005377478 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.0407      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00384    |
# |    std                  | 0.963       |
# |    value_loss           | 16.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 922         |
# |    ep_rew_mean          | 551         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 32          |
# |    time_elapsed         | 1635        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006876505 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0081     |
# |    std                  | 0.952       |
# |    value_loss           | 5.2         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 924          |
# |    ep_rew_mean          | 555          |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 33           |
# |    time_elapsed         | 1689         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0061973734 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.1         |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.84         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00476     |
# |    std                  | 0.947        |
# |    value_loss           | 9.14         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 560          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 34           |
# |    time_elapsed         | 1745         |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0060158186 |
# |    clip_fraction        | 0.0649       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.08        |
# |    explained_variance   | 0.505        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.258        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00577     |
# |    std                  | 0.94         |
# |    value_loss           | 0.793        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 928          |
# |    ep_rew_mean          | 562          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 35           |
# |    time_elapsed         | 1802         |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0075749056 |
# |    clip_fraction        | 0.0627       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.06        |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.304        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00561     |
# |    std                  | 0.937        |
# |    value_loss           | 0.749        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 930         |
# |    ep_rew_mean          | 566         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 36          |
# |    time_elapsed         | 1860        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008100507 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.183       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00637    |
# |    std                  | 0.931       |
# |    value_loss           | 0.505       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 922         |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 37          |
# |    time_elapsed         | 1914        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008234628 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.381       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00506    |
# |    std                  | 0.932       |
# |    value_loss           | 0.713       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 915          |
# |    ep_rew_mean          | 563          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 38           |
# |    time_elapsed         | 1967         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0068911957 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.04        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.15         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00418     |
# |    std                  | 0.932        |
# |    value_loss           | 4.72         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 917         |
# |    ep_rew_mean          | 566         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 39          |
# |    time_elapsed         | 2025        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009204503 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.483       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00768    |
# |    std                  | 0.928       |
# |    value_loss           | 4.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 905         |
# |    ep_rew_mean          | 565         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 40          |
# |    time_elapsed         | 2084        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010313402 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00948    |
# |    std                  | 0.919       |
# |    value_loss           | 0.316       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 903          |
# |    ep_rew_mean          | 567          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 41           |
# |    time_elapsed         | 2138         |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0057847323 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.98        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.6          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00469     |
# |    std                  | 0.909        |
# |    value_loss           | 10.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 561          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 42           |
# |    time_elapsed         | 2192         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0110592265 |
# |    clip_fraction        | 0.0772       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.95        |
# |    explained_variance   | 0.289        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.202        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00362     |
# |    std                  | 0.902        |
# |    value_loss           | 2.95         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 868         |
# |    ep_rew_mean          | 560         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 43          |
# |    time_elapsed         | 2243        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009080798 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.41        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00654    |
# |    std                  | 0.897       |
# |    value_loss           | 8.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 849         |
# |    ep_rew_mean          | 559         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 44          |
# |    time_elapsed         | 2296        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005934889 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | -0.00656    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00367    |
# |    std                  | 0.901       |
# |    value_loss           | 11.5        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 829       |
# |    ep_rew_mean          | 559       |
# | time/                   |           |
# |    fps                  | 39        |
# |    iterations           | 45        |
# |    time_elapsed         | 2351      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0082075 |
# |    clip_fraction        | 0.0869    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.94     |
# |    explained_variance   | 0.0999    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.13      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.00287  |
# |    std                  | 0.902     |
# |    value_loss           | 7.42      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 790          |
# |    ep_rew_mean          | 553          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 46           |
# |    time_elapsed         | 2405         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0056629605 |
# |    clip_fraction        | 0.0704       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.93        |
# |    explained_variance   | 0.0462       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.82         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00363     |
# |    std                  | 0.894        |
# |    value_loss           | 9.66         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 747         |
# |    ep_rew_mean          | 541         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 47          |
# |    time_elapsed         | 2458        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006967847 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.34        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00511    |
# |    std                  | 0.892       |
# |    value_loss           | 11.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 731          |
# |    ep_rew_mean          | 541          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 48           |
# |    time_elapsed         | 2514         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0063734287 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.88        |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.54         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00504     |
# |    std                  | 0.88         |
# |    value_loss           | 10.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 719         |
# |    ep_rew_mean          | 540         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 49          |
# |    time_elapsed         | 2571        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010714021 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.555       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00486    |
# |    std                  | 0.871       |
# |    value_loss           | 4.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 710         |
# |    ep_rew_mean          | 537         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 50          |
# |    time_elapsed         | 2627        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007816012 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.709       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00397    |
# |    std                  | 0.871       |
# |    value_loss           | 4.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 703         |
# |    ep_rew_mean          | 541         |
# | time/                   |             |
# |    fps                  | 38          |
# ...
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.495       |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.00452    |
# |    std                  | 0.548       |
# |    value_loss           | 1.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.2        |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 113         |
# |    time_elapsed         | 6019        |
# |    total_timesteps      | 231424      |
# | train/                  |             |
# |    approx_kl            | 0.012824678 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.637       |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00358    |
# |    std                  | 0.543       |
# |    value_loss           | 1.23        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.4       |
# |    ep_rew_mean          | 138        |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 114        |
# |    time_elapsed         | 6074       |
# |    total_timesteps      | 233472     |
# | train/                  |            |
# |    approx_kl            | 0.00848778 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.41      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.54       |
# |    n_updates            | 1130       |
# |    policy_gradient_loss | -0.00269   |
# |    std                  | 0.543      |
# |    value_loss           | 1.31       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.4       |
# |    ep_rew_mean          | 137        |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 115        |
# |    time_elapsed         | 6130       |
# |    total_timesteps      | 235520     |
# | train/                  |            |
# |    approx_kl            | 0.01144088 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.39      |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.31       |
# |    n_updates            | 1140       |
# |    policy_gradient_loss | -0.00354   |
# |    std                  | 0.535      |
# |    value_loss           | 1.03       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.2        |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 116         |
# |    time_elapsed         | 6185        |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.009116895 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.523       |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | 0.000282    |
# |    std                  | 0.527       |
# |    value_loss           | 1.2         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 58.4       |
# |    ep_rew_mean          | 139        |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 117        |
# |    time_elapsed         | 6240       |
# |    total_timesteps      | 239616     |
# | train/                  |            |
# |    approx_kl            | 0.01194171 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.32      |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.521      |
# |    n_updates            | 1160       |
# |    policy_gradient_loss | -0.00201   |
# |    std                  | 0.525      |
# |    value_loss           | 1.09       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.1        |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 118         |
# |    time_elapsed         | 6296        |
# |    total_timesteps      | 241664      |
# | train/                  |             |
# |    approx_kl            | 0.008734589 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.438       |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00247    |
# |    std                  | 0.527       |
# |    value_loss           | 1.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.7        |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 119         |
# |    time_elapsed         | 6354        |
# |    total_timesteps      | 243712      |
# | train/                  |             |
# |    approx_kl            | 0.009923381 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.485       |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | -0.00292    |
# |    std                  | 0.524       |
# |    value_loss           | 1.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.6        |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 120         |
# |    time_elapsed         | 6411        |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.017443422 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.324       |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.0036     |
# |    std                  | 0.52        |
# |    value_loss           | 0.806       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.2        |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 121         |
# |    time_elapsed         | 6467        |
# |    total_timesteps      | 247808      |
# | train/                  |             |
# |    approx_kl            | 0.013702011 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.527       |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.0034     |
# |    std                  | 0.517       |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.3        |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 122         |
# |    time_elapsed         | 6526        |
# |    total_timesteps      | 249856      |
# | train/                  |             |
# |    approx_kl            | 0.013350076 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.462       |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | -0.000554   |
# |    std                  | 0.513       |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.7        |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 123         |
# |    time_elapsed         | 6582        |
# |    total_timesteps      | 251904      |
# | train/                  |             |
# |    approx_kl            | 0.012088994 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.302       |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.00061    |
# |    std                  | 0.51        |
# |    value_loss           | 0.937       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57          |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 124         |
# |    time_elapsed         | 6640        |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.012949565 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.546       |
# |    n_updates            | 1230        |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.51        |
# |    value_loss           | 1.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 125         |
# |    time_elapsed         | 6697        |
# |    total_timesteps      | 256000      |
# | train/                  |             |
# |    approx_kl            | 0.012939554 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.738       |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | 0.000668    |
# |    std                  | 0.504       |
# |    value_loss           | 0.944       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.5         |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 126          |
# |    time_elapsed         | 6753         |
# |    total_timesteps      | 258048       |
# | train/                  |              |
# |    approx_kl            | 0.0104718525 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.341        |
# |    n_updates            | 1250         |
# |    policy_gradient_loss | 0.00129      |
# |    std                  | 0.499        |
# |    value_loss           | 0.908        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.9        |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 127         |
# |    time_elapsed         | 6809        |
# |    total_timesteps      | 260096      |
# | train/                  |             |
# |    approx_kl            | 0.010464814 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.52        |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.000556   |
# |    std                  | 0.497       |
# |    value_loss           | 0.737       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.6        |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 128         |
# |    time_elapsed         | 6870        |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.010041165 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.436       |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | -0.00207    |
# |    std                  | 0.499       |
# |    value_loss           | 0.615       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 129         |
# |    time_elapsed         | 6933        |
# |    total_timesteps      | 264192      |
# | train/                  |             |
# |    approx_kl            | 0.012823312 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.166       |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.00354    |
# |    std                  | 0.491       |
# |    value_loss           | 0.663       |
# -----------------------------------------
